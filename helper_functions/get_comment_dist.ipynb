# %%
import re
import os
import pandas as pd
from collections import defaultdict
import matplotlib.pyplot as plt
import numpy as np
from typing import Dict
plt.style.use('default')
CSV_EXTENSION = '.csv'
SINGLE_FILE_KEY = 'single_file'
import warnings
from get_comment_dist import get_comment_to_ckpt_by_task
warnings.filterwarnings('ignore')

def process_horizon_categories_output(row):
    # Check if the row is a string
    if isinstance(row, str):
        # Define the regular expression pattern
        pattern = r"(?P<type>\w+) '.*?' used at line (?P<usage_line>\d+) is defined at line (?P<def_line>\d+)"

        # Use the re.findall function to find all matches in the row
        matches = re.findall(pattern, row)

        # Convert the matches to the required format
        results = []
        for match in matches:
            type, usage_line, def_line = match
            results.append((type, int(usage_line), int(def_line)))

        return results
    else:
        # If the row is not a string, return an empty list
        return []

def expand_lists_to_rows(df, column):
    # Create a new DataFrame where each item in the 'Processed' column is expanded into its own row
    expanded_df = df.explode(column)

    # Split the 'Processed' column into separate 'Type', 'usage_line', and 'def_line' columns
    expanded_df[['Type', 'usage_line', 'def_line']] = pd.DataFrame(expanded_df[column].tolist(), index=expanded_df.index)
    
    # Calculate the absolute differences between 'usage_line' and 'def_line'
    expanded_df['abs_diff'] = abs(expanded_df['usage_line'] - expanded_df['def_line'])

    # Drop the 'Processed' column
    expanded_df = expanded_df.drop(columns=[column])

    return expanded_df

def process_max_range(expanded_df, groupby_col=['code_task', 'start_line', 'end_line']):
    # Drop NaN values
    expanded_df = expanded_df.dropna(subset=groupby_col)
    # Reset the index
    expanded_df = expanded_df.reset_index(drop=True)
    # Find the index of the row with the maximum difference for each group
    idx = expanded_df.groupby(groupby_col)['abs_diff'].idxmax()
    # Print out the number of rows in the original DataFrame, dropped, and the number of rows after the groupby operation
    print(f"Original DataFrame: {len(expanded_df)} rows")
    # print(f"Rows dropped: {len(expanded_df) - len(idx)}")
    print(f"DataFrame after groupby: {len(idx)} rows")
    # Keep only the rows with the maximum difference
    expanded_df = expanded_df.loc[idx]
    return expanded_df

def extract_info(csv_file):
    # Remove the file extension
    name_without_ext = csv_file.split('.csv')[0]

    # Split the name into parts
    parts = name_without_ext.split('_')

    # Extract the information
    info = {
        'model_name': parts[0],
        'gen_mode': '_'.join(parts[1:3]),
        'task': parts[3],
        'time': '_'.join(parts[4:])
    }

    return info

def group_by_res(folder_path, group_by_keys=['model_name','gen_mode'], group_gpt_4_turbo=True, debug_print=False):
    # Get a list of all CSV files in the folder
    csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

    # Create a dictionary to store the groups
    groups = defaultdict(list)

    # Group the CSV files
    for csv_file in csv_files:
        # Extract the information from the file name
        info = extract_info(csv_file)

        # Get the group key
        group_key_parts = [info[key] for key in group_by_keys]
        group_key = '_'.join(group_key_parts)

        # If group_gpt_4_turbo is True, treat 'gpt-4-turbo' and 'gpt-4-turbo-2024-04-09' as the same model_name
        if group_gpt_4_turbo and 'model_name' in group_by_keys and 'gpt-4-turbo' in group_key:
            group_key = group_key.replace('gpt-4-turbo-2024-04-09', 'gpt-4-turbo')

        # Add the CSV file to the group
        groups[group_key].append(csv_file)

    # Concatenate the CSV files in each group
    for group_key, group_files in groups.items():
        if debug_print:
            print(f"Grouped by {group_by_keys} and combined {', '.join(group_files)}")
        dfs = [pd.read_csv(os.path.join(folder_path, csv_file)) for csv_file in group_files]
        df_group = pd.concat(dfs, ignore_index=True)
        groups[group_key] = df_group

    return groups

def groupby_sanity_check(grouped_dfs):
    for group_key, df in grouped_dfs.items():
        print(f"Group Key: {group_key}")
        print(len(df))
        print("\n")
        
def process_folder(folder_path: str) -> Dict[str, pd.DataFrame]:
    global col_to_check
    # Check if the path is a directory
    if os.path.isdir(folder_path):
        # Group and concatenate the CSV files
        grouped_dfs = group_by_res(folder_path)
    elif os.path.isfile(folder_path) and folder_path.endswith(CSV_EXTENSION):
        # If the path is a CSV file, read it into a DataFrame
        grouped_dfs = {SINGLE_FILE_KEY: pd.read_csv(folder_path)}
    else:
        # If the path is not a directory and not a CSV file, raise an error
        raise ValueError(f"Invalid path: {folder_path}. Path must be a directory containing CSV files or a CSV file.")
    processed_dfs = {}
    for group_key, df in grouped_dfs.items():
        init_row_num = len(df)
        # Columns to check for NaN values
        initial_cols_to_check = ['horizon_categories_output', 'horizon_freq_analysis']

        # Drop rows with NaN values in the initial_cols_to_check
        df_after_initial_drop = df.dropna(subset=initial_cols_to_check)

        # Process the 'horizon_categories_output' column
        df_after_initial_drop['Processed'] = df_after_initial_drop['horizon_categories_output'].apply(process_horizon_categories_output)

        # Expand the lists to rows
        expanded_df = expand_lists_to_rows(df_after_initial_drop, 'Processed')

        # Additional columns to check for NaN values
        additional_cols_to_check = ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', col_to_check]

        # Drop rows with NaN values in the additional_cols_to_check
        expanded_df_filtered = expanded_df.dropna(subset=additional_cols_to_check)

        print("#############################################")
        # Print out the number of rows in the original DataFrame, and dropped due to NaN values in the cols_to_check
        print(f"Original DataFrame: {init_row_num} rows")
        print(f"Rows dropped due to NaN in initial columns {initial_cols_to_check}: {init_row_num - len(df_after_initial_drop)}")
        print(f"Rows after expansion: {len(expanded_df)} rows")
        print(f"Rows dropped due to NaN in additional columns {additional_cols_to_check}: {len(expanded_df) - len(expanded_df_filtered)}")

        # Process the max range
        df = process_max_range(expanded_df_filtered)

        processed_dfs[group_key] = df

    return processed_dfs

def convert_to_float(val: str) -> float:
    try:
        return float(val)
    except ValueError:
        parts = val.split('/')
        if len(parts) == 2:
            num, denom = parts
            if denom != '0':
                return float(num) / float(denom)
        return 0.0
    
def draw_histogram(df, group_key, show_pass_dist=False, bins=30):
    global col_to_check
    plt.figure(dpi=400)
    # Calculate the absolute differences between 'usage_line' and 'def_line'
    differences = df['abs_diff']

    # Define the bin edges
    bin_edges = np.linspace(differences.min(), differences.max(), bins+1)

    # Create a histogram of the differences
    plt.hist(differences, bins=bin_edges, edgecolor='black', alpha=0.5, label='All data')

    if show_pass_dist:
        # Convert 'col_to_check' to float and filter the DataFrame where it is 1
        df[col_to_check] = df[col_to_check].apply(convert_to_float)
        filtered_df = df[df[col_to_check] == 1]

        # Create a histogram of the differences for the filtered DataFrame
        plt.hist(filtered_df['abs_diff'], bins=bin_edges, edgecolor='black', color='red', alpha=0.5, label='gen_code_passed')

    # Set the title and labels
    plt.title(group_key)
    plt.xlabel('Recall Distance')
    plt.ylabel('Frequency')

    # Add a legend
    plt.legend()

    # Display the histogram
    plt.show()

def plot_histograms(groups, show_pass_dist=True):
    global col_to_check
    for group_key, df_group in groups.items():
        print(f"Plotting histogram for group: {group_key}")
        draw_histogram(df_group, group_key, show_pass_dist)

def get_difference(row):
    start_line = row['start_line']
    list_of_tuples = row['list_of_tuples']
    matching_tuples = [t for t in list_of_tuples if t[0] == start_line]
    for t in matching_tuples:
        return t[0] - t[1]
    return None


def classify_and_calculate(df, program_type, task_type, short_range, medium_range, report_err_bar=True):
    global col_to_check
    def classify_abs_diff(x):
        if x <= short_range:
            return 'Short'
        elif x > short_range:
            return 'Long'
        else:
            return None
    df['list_of_tuples'] = df['code_task'].apply(lambda x: get_comment_to_ckpt_by_task(x, program_type, task_type))
    df['comment_dist'] = df.apply(get_difference, axis=1)
    df['range_class'] = df['comment_dist'].apply(classify_abs_diff)
    df[col_to_check] = df[col_to_check].apply(convert_to_float)

    total_counts = df.groupby('range_class').size()
    pass_counts = df[df[col_to_check] == 1].groupby('range_class').size()
    # Reindex the pass_counts to include all range classes & fill 0 for NaN values
    pass_counts = pass_counts.reindex(total_counts.index, fill_value=0)
    if report_err_bar:
        percentages, err_bar = cal_err_bar(pass_counts, total_counts)
        err_bar = err_bar.values
    else:
        percentages = pass_counts / total_counts * 100
        err_bar = None

    result_df = pd.DataFrame({
        'range_class': total_counts.index,
        'total_counts': total_counts.values,
        'passed_counts': pass_counts.values,
        'percentages': percentages.values
    })

    result_df['range_class'] = pd.Categorical(result_df['range_class'], categories=['Short', 'Medium', 'Long'], ordered=True)
    result_df = result_df.sort_values('range_class')
    if report_err_bar:
        result_df['percentages'] = result_df.apply(lambda row: f"{row['percentages']*100:.1f} ± {err_bar[row.name]*100:.1f}", axis=1)
    else:
        result_df['percentages'] = result_df['percentages'].apply(lambda x: f"{x:.1f}%")

    return percentages, result_df

# percentages, result_df = classify_and_calculate(combined_df['gpt-4-turbo_with_afterlines'], 30, 100)
# result_df

def process_all_dfs(combined_df, program_type, task_type, short_range, medium_range):
    all_results = []
    for key in combined_df:
        percentages, result_df = classify_and_calculate(combined_df[key], program_type, task_type, short_range, medium_range)
        # import pdb; pdb.set_trace()
        result_df.insert(0, 'key', key)
        all_results.append(result_df)
    final_df = pd.concat(all_results, ignore_index=True)
    return final_df

def split_df(final_df):
    unique_keys = final_df['key'].unique()
    sub_dfs = {key: final_df[final_df['key'] == key].drop(columns='key') for key in unique_keys}
    return sub_dfs

def process_and_plot(folder_path, col_to_check):
    # Set the global variable
    combined_df = process_folder(folder_path)
    # Call the function
    # plot_histograms(combined_df)
    return combined_df

def process_and_display(combined_df, program_type, task_type, short_range, medium_range):
    # Set the short and medium ranges
    final_df = process_all_dfs(combined_df, program_type, task_type, short_range, medium_range)

    sub_dfs = split_df(final_df)

    # Sort the keys based on model_name and gen_mode
    sorted_keys = sorted(sub_dfs.keys(), key=lambda x: (x.rsplit('_', 1)[0], x.rsplit('_', 1)[1]))

    for key in sorted_keys:
        df = sub_dfs[key]
        print(f"Key: {key}")
        display(df)
    return sub_dfs

def bootstrap_resampling(pass_count, total_count, num_resamples=10000):
    # Calculate model's performance
    performance = pass_count / total_count

    # Generate bootstrap resamples
    resamples = np.random.choice([0, 1], size=(num_resamples, total_count), p=[1-performance, performance])

    # Calculate pass count for each resample
    resample_pass_counts = resamples.sum(axis=1)

    # Calculate performance for each resample
    resample_performances = resample_pass_counts / total_count

    # Calculate average and 1.96 standard deviations of resample performances
    avg_performance = resample_performances.mean()
    std_dev_performance = resample_performances.std()

    return avg_performance, 1.96 * std_dev_performance

def cal_err_bar(pass_counts, total_counts, num_resamples=10000):
    percentages = []
    err_bars = []
    for pass_count, total_count in zip(pass_counts, total_counts):
        # Use bootstrap resampling to calculate average performance and error bar
        percentage, err_bar = bootstrap_resampling(pass_count, total_count, num_resamples)
        percentages.append(percentage)
        err_bars.append(err_bar)

    return pd.Series(percentages, index=total_counts.index), pd.Series(err_bars, index=total_counts.index)

def save_df_dict_to_csv_with_keys(df_dict, output_file_name):
    final_df = pd.DataFrame()

    for key, df in df_dict.items():
        key_row = pd.DataFrame({col: [key] if col == list(df.columns)[0] else [pd.NA] for col in df.columns})
        final_df = pd.concat([final_df, key_row, df], ignore_index=True)

    final_df.to_csv(output_file_name, index=False)

def analyze_language_results(language, analysis_type):
    print(f"################### Analyzing {language} {analysis_type} ###################")
    print()
    settings = {
        "Python": {
            "Completion": {"folder_path": "../Analysis_Results/storage_server/Python_all_res/Completion/4th_post_process_reason_update/Update_labels", "save_file_name": "Python_Completion_grouped_by_comment_dist.csv", "short_range": 10, "medium_range": 30},
            "infilling": {"folder_path": "../Analysis_Results/storage_server/Python_all_res/Infilling/4th_post_process_reason_update/Update_labels", "save_file_name": "Python_Infilling_grouped_by_comment_dist.csv", "short_range": 10, "medium_range": 30}
        },
        "Java": {
            "Completion": {"folder_path": "../Analysis_Results/storage_server/Java_all_res/Completion/4th_post_process_reason_update/Update_labels", "save_file_name": "Java_Completion_grouped_by_comment_dist.csv", "short_range": 10, "medium_range": 30},
            "infilling": {"folder_path": "../Analysis_Results/storage_server/Java_all_res/Infilling/4th_post_process_reason_update/Update_labels", "save_file_name": "Java_Infilling_grouped_by_comment_dist.csv", "short_range": 10, "medium_range": 30}
        }
    }
    program_type = language
    task_type = f"checkpoint_LN_{analysis_type}"
    setting = settings[language][analysis_type]
    folder_path = setting['folder_path']
    save_file_name = setting['save_file_name']
    short_range = setting['short_range']
    medium_range = setting['medium_range']

    combined_df = process_and_plot(folder_path, col_to_check)
    dict_dfs = process_and_display(combined_df, program_type, task_type, short_range, medium_range)
    save_df_dict_to_csv_with_keys(dict_dfs, save_file_name)

col_to_check = 'post_process_pass_ratio'
# Example usage
analyze_language_results("Python", "Completion")
analyze_language_results("Python", "infilling")
analyze_language_results("Java", "Completion")
analyze_language_results("Java", "infilling")
# Out:
# ################### Analyzing Python Completion ###################
#
# #############################################
# Original DataFrame: 212 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 2
# Rows after expansion: 1175 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 3
# Original DataFrame: 1172 rows
# DataFrame after groupby: 207 rows
# #############################################
# Original DataFrame: 212 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 2
# Rows after expansion: 1175 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 3
# Original DataFrame: 1172 rows
# DataFrame after groupby: 207 rows
# #############################################
# Original DataFrame: 212 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 2
# Rows after expansion: 1175 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 3
# Original DataFrame: 1172 rows
# DataFrame after groupby: 207 rows
# #############################################
# Original DataFrame: 212 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 2
# Rows after expansion: 1175 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 3
# Original DataFrame: 1172 rows
# DataFrame after groupby: 207 rows
# #############################################
# Original DataFrame: 212 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 2
# Rows after expansion: 1175 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 3
# Original DataFrame: 1172 rows
# DataFrame after groupby: 207 rows
# #############################################
# Original DataFrame: 212 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 2
# Rows after expansion: 1175 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 3
# Original DataFrame: 1172 rows
# DataFrame after groupby: 207 rows
# #############################################
# Original DataFrame: 212 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 2
# Rows after expansion: 1175 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 3
# Original DataFrame: 1172 rows
# DataFrame after groupby: 207 rows
# #############################################
# Original DataFrame: 212 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 2
# Rows after expansion: 1175 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 3
# Original DataFrame: 1172 rows
# DataFrame after groupby: 207 rows
# #############################################
# Original DataFrame: 212 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 2
# Rows after expansion: 1175 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 3
# Original DataFrame: 1172 rows
# DataFrame after groupby: 207 rows
# #############################################
# Original DataFrame: 212 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 2
# Rows after expansion: 1175 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 3
# Original DataFrame: 1172 rows
# DataFrame after groupby: 207 rows
# Key: Meta-Llama-3-70B-Instruct_no_afterlines
#   range_class  total_counts  passed_counts percentages
# 2       Short           105             56  53.3 ± 9.5
# 3        Long           102             37  36.3 ± 9.3
# Key: Meta-Llama-3-8B-Instruct_no_afterlines
#    range_class  total_counts  passed_counts percentages
# 14       Short           105             37  35.2 ± 9.2
# 15        Long           102             27  26.5 ± 8.6
# Key: claude-3-haiku-20240307_no_afterlines
#   range_class  total_counts  passed_counts percentages
# 8       Short           105             37  35.3 ± 9.0
# 9        Long           102             20  19.6 ± 7.7
# Key: claude-3-opus-20240229_no_afterlines
#   range_class  total_counts  passed_counts percentages
# 6       Short           105             34  32.5 ± 9.0
# 7        Long           102             16  15.7 ± 7.1
# Key: claude-3-sonnet-20240229_no_afterlines
#    range_class  total_counts  passed_counts percentages
# 18       Short           105             36  34.3 ± 9.0
# 19        Long           102             20  19.6 ± 7.6
# Key: deepseek-coder-1.3b-instruct_no_afterlines
#   range_class  total_counts  passed_counts percentages
# 4       Short           105             14  13.4 ± 6.5
# 5        Long           102             11  10.8 ± 6.0
# Key: deepseek-coder-7b-instruct_no_afterlines
#    range_class  total_counts  passed_counts percentages
# 12       Short           105             51  48.5 ± 9.5
# 13        Long           102             41  40.2 ± 9.4
# Key: gpt-3.5-turbo-0125_no_afterlines
#    range_class  total_counts  passed_counts percentages
# 10       Short           105             62  59.1 ± 9.5
# 11        Long           102             46  45.0 ± 9.7
# Key: gpt-4-turbo_no_afterlines
#    range_class  total_counts  passed_counts percentages
# 16       Short           105             67  63.8 ± 9.2
# 17        Long           102             49  48.0 ± 9.7
# Key: phi-3-mini-4k_no_afterlines
#   range_class  total_counts  passed_counts percentages
# 0       Short           105             13  12.4 ± 6.4
# 1        Long           102              3   2.9 ± 3.3
# ################### Analyzing Python infilling ###################
#
# #############################################
# Original DataFrame: 382 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 2
# Rows after expansion: 1447 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 6
# Original DataFrame: 1441 rows
# DataFrame after groupby: 374 rows
# #############################################
# Original DataFrame: 382 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 2
# Rows after expansion: 1447 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 6
# Original DataFrame: 1441 rows
# DataFrame after groupby: 374 rows
# #############################################
# Original DataFrame: 382 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 2
# Rows after expansion: 1447 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 6
# Original DataFrame: 1441 rows
# DataFrame after groupby: 374 rows
# #############################################
# Original DataFrame: 382 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 2
# Rows after expansion: 1447 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 6
# Original DataFrame: 1441 rows
# DataFrame after groupby: 374 rows
# #############################################
# Original DataFrame: 382 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 2
# Rows after expansion: 1447 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 6
# Original DataFrame: 1441 rows
# DataFrame after groupby: 374 rows
# #############################################
# Original DataFrame: 382 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 2
# Rows after expansion: 1447 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 6
# Original DataFrame: 1441 rows
# DataFrame after groupby: 374 rows
# #############################################
# Original DataFrame: 382 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 2
# Rows after expansion: 1447 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 6
# Original DataFrame: 1441 rows
# DataFrame after groupby: 374 rows
# #############################################
# Original DataFrame: 382 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 2
# Rows after expansion: 1447 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 6
# Original DataFrame: 1441 rows
# DataFrame after groupby: 374 rows
# #############################################
# Original DataFrame: 382 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 2
# Rows after expansion: 1447 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 6
# Original DataFrame: 1441 rows
# DataFrame after groupby: 374 rows
# #############################################
# Original DataFrame: 382 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 2
# Rows after expansion: 1447 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 6
# Original DataFrame: 1441 rows
# DataFrame after groupby: 374 rows
# Key: Meta-Llama-3-70B-Instruct_with_afterlines
#   range_class  total_counts  passed_counts percentages
# 8       Short           236            155  65.7 ± 6.0
# 9        Long           138             49  35.5 ± 8.0
# Key: Meta-Llama-3-8B-Instruct_with_afterlines
#    range_class  total_counts  passed_counts percentages
# 18       Short           236             71  30.1 ± 5.9
# 19        Long           138             31  22.5 ± 7.0
# Key: claude-3-haiku-20240307_with_afterlines
#    range_class  total_counts  passed_counts percentages
# 14       Short           236             98  41.5 ± 6.4
# 15        Long           138             31  22.5 ± 7.0
# Key: claude-3-opus-20240229_with_afterlines
#   range_class  total_counts  passed_counts percentages
# 4       Short           236            135  57.2 ± 6.3
# 5        Long           138             46  33.3 ± 7.9
# Key: claude-3-sonnet-20240229_with_afterlines
#    range_class  total_counts  passed_counts percentages
# 16       Short           236            134  56.8 ± 6.3
# 17        Long           138             49  35.6 ± 8.0
# Key: deepseek-coder-1.3b-instruct_with_afterlines
#   range_class  total_counts  passed_counts percentages
# 2       Short           236             24  10.2 ± 3.9
# 3        Long           138              6   4.3 ± 3.4
# Key: deepseek-coder-7b-instruct_with_afterlines
#    range_class  total_counts  passed_counts percentages
# 10       Short           236             33  14.0 ± 4.5
# 11        Long           138              8   5.8 ± 3.9
# Key: gpt-3.5-turbo-0125_with_afterlines
#   range_class  total_counts  passed_counts percentages
# 0       Short           236             96  40.7 ± 6.3
# 1        Long           138             36  26.0 ± 7.3
# Key: gpt-4-turbo_with_afterlines
#   range_class  total_counts  passed_counts percentages
# 6       Short           236            178  75.5 ± 5.5
# 7        Long           138             79  57.3 ± 8.2
# Key: phi-3-mini-4k_with_afterlines
#    range_class  total_counts  passed_counts percentages
# 12       Short           236             13   5.5 ± 2.9
# 13        Long           138              5   3.7 ± 3.1
# ################### Analyzing Java Completion ###################
#
# #############################################
# Original DataFrame: 286 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 8
# Rows after expansion: 1274 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1274 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 286 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 8
# Rows after expansion: 1274 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1274 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 286 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 8
# Rows after expansion: 1274 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1274 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 286 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 8
# Rows after expansion: 1274 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1274 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 286 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 8
# Rows after expansion: 1274 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1274 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 286 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 8
# Rows after expansion: 1274 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1274 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 286 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 8
# Rows after expansion: 1274 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1274 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 286 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 8
# Rows after expansion: 1274 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1274 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 286 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 8
# Rows after expansion: 1274 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1274 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 286 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 8
# Rows after expansion: 1274 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1274 rows
# DataFrame after groupby: 278 rows
# Key: Meta-Llama-3-70B-Instruct_no_afterlines
#    range_class  total_counts  passed_counts  percentages
# 10       Short           193            114   59.1 ± 6.9
# 11        Long            85             36  42.3 ± 10.5
# Key: Meta-Llama-3-8B-Instruct_no_afterlines
#   range_class  total_counts  passed_counts percentages
# 2       Short           193             63  32.6 ± 6.5
# 3        Long            85             10  11.7 ± 6.8
# Key: claude-3-haiku-20240307_no_afterlines
#   range_class  total_counts  passed_counts  percentages
# 8       Short           193             99   51.3 ± 7.1
# 9        Long            85             40  47.1 ± 10.7
# Key: claude-3-opus-20240229_no_afterlines
#    range_class  total_counts  passed_counts percentages
# 16       Short           193            134  69.4 ± 6.5
# 17        Long            85             58  68.2 ± 9.9
# Key: claude-3-sonnet-20240229_no_afterlines
#   range_class  total_counts  passed_counts  percentages
# 4       Short           193            117   60.6 ± 6.9
# 5        Long            85             38  44.7 ± 10.6
# Key: deepseek-coder-1.3b-instruct_no_afterlines
#   range_class  total_counts  passed_counts percentages
# 6       Short           193             37  19.1 ± 5.6
# 7        Long            85              8   9.4 ± 6.1
# Key: deepseek-coder-7b-instruct_no_afterlines
#    range_class  total_counts  passed_counts percentages
# 18       Short           193             95  49.2 ± 7.1
# 19        Long            85             22  25.9 ± 9.4
# Key: gpt-3.5-turbo-0125_no_afterlines
#    range_class  total_counts  passed_counts percentages
# 14       Short           193            101  52.3 ± 7.0
# 15        Long            85             17  20.0 ± 8.5
# Key: gpt-4-turbo_no_afterlines
#   range_class  total_counts  passed_counts  percentages
# 0       Short           193            133   69.0 ± 6.5
# 1        Long            85             39  45.9 ± 10.6
# Key: phi-3-mini-4k_no_afterlines
#    range_class  total_counts  passed_counts percentages
# 12       Short           193             25  13.0 ± 4.8
# 13        Long            85              5   5.9 ± 5.0
# ################### Analyzing Java infilling ###################
#
# #############################################
# Original DataFrame: 283 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 5
# Rows after expansion: 1272 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1272 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 283 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 5
# Rows after expansion: 1272 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1272 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 283 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 5
# Rows after expansion: 1272 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1272 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 283 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 5
# Rows after expansion: 1272 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1272 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 283 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 5
# Rows after expansion: 1272 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1272 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 283 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 5
# Rows after expansion: 1272 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1272 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 283 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 5
# Rows after expansion: 1272 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1272 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 283 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 5
# Rows after expansion: 1272 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1272 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 283 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 5
# Rows after expansion: 1272 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1272 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 283 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 5
# Rows after expansion: 1272 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1272 rows
# DataFrame after groupby: 278 rows
# Key: Meta-Llama-3-70B-Instruct_with_afterlines
#    range_class  total_counts  passed_counts  percentages
# 16       Short           206            121   58.8 ± 6.7
# 17        Long            72             35  48.7 ± 11.5
# Key: Meta-Llama-3-8B-Instruct_with_afterlines
#    range_class  total_counts  passed_counts percentages
# 12       Short           206             52  25.2 ± 5.9
# 13        Long            72             15  20.7 ± 9.3
# Key: claude-3-haiku-20240307_with_afterlines
#    range_class  total_counts  passed_counts percentages
# 10       Short           206             71  34.5 ± 6.5
# 11        Long            72             14  19.3 ± 9.1
# Key: claude-3-opus-20240229_with_afterlines
#    range_class  total_counts  passed_counts  percentages
# 18       Short           206            159   77.2 ± 5.7
# 19        Long            72             44  61.1 ± 11.3
# Key: claude-3-sonnet-20240229_with_afterlines
#   range_class  total_counts  passed_counts  percentages
# 8       Short           206            132   64.1 ± 6.6
# 9        Long            72             28  39.0 ± 11.2
# Key: deepseek-coder-1.3b-instruct_with_afterlines
#   range_class  total_counts  passed_counts percentages
# 4       Short           206             12   5.8 ± 3.2
# 5        Long            72              2   2.8 ± 3.8
# Key: deepseek-coder-7b-instruct_with_afterlines
#   range_class  total_counts  passed_counts percentages
# 2       Short           206             15   7.3 ± 3.6
# 3        Long            72              1   1.4 ± 2.7
# Key: gpt-3.5-turbo-0125_with_afterlines
#   range_class  total_counts  passed_counts percentages
# 6       Short           206             59  28.6 ± 6.2
# 7        Long            72             15  20.8 ± 9.5
# Key: gpt-4-turbo_with_afterlines
#   range_class  total_counts  passed_counts  percentages
# 0       Short           206            159   77.2 ± 5.8
# 1        Long            72             48  66.7 ± 10.9
# Key: phi-3-mini-4k_with_afterlines
#    range_class  total_counts  passed_counts percentages
# 14       Short           206             19   9.2 ± 3.9
# 15        Long            72              3   4.2 ± 4.6

# %%
def test_comment_distance_classification(folder_path, program_type, task_type, short_range=10):
    combined_df = process_and_plot(folder_path, col_to_check)
    for key in combined_df:
        print("################ Analyzing", key, "################")
        df = combined_df[key]

        def classify_abs_diff(x):
            if x <= short_range:
                return 'Short'
            elif x > short_range:
                return 'Long'
            else:
                return None

        df['list_of_tuples'] = df['code_task'].apply(lambda x: get_comment_to_ckpt_by_task(x, program_type, task_type))
        df['comment_dist'] = df.apply(get_difference, axis=1)
        df['range_class'] = df['comment_dist'].apply(classify_abs_diff)
        df[col_to_check] = df[col_to_check].apply(convert_to_float)

        non_rows = df[df['comment_dist'].isnull()]
        len_non_rows = len(non_rows)
        print(f"Number of rows with NaN values in 'comment_dist': {len_non_rows}")

        display(df)

language = "Java"
analysis_type = "Completion"

settings = {
        "Python": {
            "Completion": {"folder_path": "../Analysis_Results/storage_server/Python_all_res/Completion/4th_post_process_reason_update/Update_labels", "save_file_name": "Python_Completion_grouped_by_comment_dist.csv", "short_range": 10, "medium_range": 30},
            "infilling": {"folder_path": "../Analysis_Results/storage_server/Python_all_res/Infilling/4th_post_process_reason_update/Update_labels", "save_file_name": "Python_Infilling_grouped_by_comment_dist.csv", "short_range": 10, "medium_range": 30}
        },
        "Java": {
            "Completion": {"folder_path": "../Analysis_Results/storage_server/Java_all_res/Completion/4th_post_process_reason_update/Update_labels", "save_file_name": "Java_Completion_grouped_by_comment_dist.csv", "short_range": 10, "medium_range": 30},
            "infilling": {"folder_path": "../Analysis_Results/storage_server/Java_all_res/Infilling/4th_post_process_reason_update/Update_labels", "save_file_name": "Java_Infilling_grouped_by_comment_dist.csv", "short_range": 10, "medium_range": 30}
        }
    }
program_type = language
task_type = f"checkpoint_LN_{analysis_type}"
setting = settings[language][analysis_type]
folder_path = setting['folder_path']
save_file_name = setting['save_file_name']
short_range = setting['short_range']
medium_range = setting['medium_range']

test_comment_distance_classification(folder_path, program_type, task_type, short_range=10)
# Out:
# Grouped by ['model_name', 'gen_mode'] and combined gpt-4-turbo_no_afterlines_MTreeTester_06_03_04_07.csv, gpt-4-turbo_no_afterlines_FactorizationTester_06_03_04_05.csv, gpt-4-turbo_no_afterlines_SparseArrayTester_06_03_03_58.csv, gpt-4-turbo_no_afterlines_CounterTester_06_03_04_02.csv, gpt-4-turbo_no_afterlines_RNGTester_06_03_04_02.csv, gpt-4-turbo_no_afterlines_DoubleVectorTester_06_03_04_00.csv, gpt-4-turbo_no_afterlines_TopKTester_06_03_04_01.csv, gpt-4-turbo_no_afterlines_DoubleMatrixTester_06_03_04_06.csv
# Grouped by ['model_name', 'gen_mode'] and combined Meta-Llama-3-8B-Instruct_no_afterlines_TopKTester_06_03_04_05.csv, Meta-Llama-3-8B-Instruct_no_afterlines_FactorizationTester_06_03_04_03.csv, Meta-Llama-3-8B-Instruct_no_afterlines_SparseArrayTester_06_03_04_03.csv, Meta-Llama-3-8B-Instruct_no_afterlines_DoubleVectorTester_06_03_03_58.csv, Meta-Llama-3-8B-Instruct_no_afterlines_RNGTester_06_03_04_03.csv, Meta-Llama-3-8B-Instruct_no_afterlines_CounterTester_06_03_04_06.csv, Meta-Llama-3-8B-Instruct_no_afterlines_DoubleMatrixTester_06_03_04_05.csv, Meta-Llama-3-8B-Instruct_no_afterlines_MTreeTester_06_03_04_00.csv
# Grouped by ['model_name', 'gen_mode'] and combined claude-3-sonnet-20240229_no_afterlines_MTreeTester_06_03_04_02.csv, claude-3-sonnet-20240229_no_afterlines_DoubleMatrixTester_06_03_03_59.csv, claude-3-sonnet-20240229_no_afterlines_TopKTester_06_03_03_58.csv, claude-3-sonnet-20240229_no_afterlines_SparseArrayTester_06_03_04_02.csv, claude-3-sonnet-20240229_no_afterlines_RNGTester_06_03_04_03.csv, claude-3-sonnet-20240229_no_afterlines_FactorizationTester_06_03_04_00.csv, claude-3-sonnet-20240229_no_afterlines_CounterTester_06_03_04_00.csv, claude-3-sonnet-20240229_no_afterlines_DoubleVectorTester_06_03_04_06.csv
# Grouped by ['model_name', 'gen_mode'] and combined deepseek-coder-1.3b-instruct_no_afterlines_DoubleMatrixTester_06_03_04_07.csv, deepseek-coder-1.3b-instruct_no_afterlines_CounterTester_06_03_04_00.csv, deepseek-coder-1.3b-instruct_no_afterlines_TopKTester_06_03_04_07.csv, deepseek-coder-1.3b-instruct_no_afterlines_DoubleVectorTester_06_03_04_02.csv, deepseek-coder-1.3b-instruct_no_afterlines_FactorizationTester_06_03_04_02.csv, deepseek-coder-1.3b-instruct_no_afterlines_RNGTester_06_03_04_04.csv, deepseek-coder-1.3b-instruct_no_afterlines_SparseArrayTester_06_03_03_59.csv, deepseek-coder-1.3b-instruct_no_afterlines_MTreeTester_06_03_04_04.csv
# Grouped by ['model_name', 'gen_mode'] and combined claude-3-haiku-20240307_no_afterlines_RNGTester_06_03_03_58.csv, claude-3-haiku-20240307_no_afterlines_TopKTester_06_03_03_59.csv, claude-3-haiku-20240307_no_afterlines_DoubleMatrixTester_06_03_04_00.csv, claude-3-haiku-20240307_no_afterlines_SparseArrayTester_06_03_04_02.csv, claude-3-haiku-20240307_no_afterlines_CounterTester_06_03_04_05.csv, claude-3-haiku-20240307_no_afterlines_MTreeTester_06_03_04_05.csv, claude-3-haiku-20240307_no_afterlines_FactorizationTester_06_03_04_02.csv, claude-3-haiku-20240307_no_afterlines_DoubleVectorTester_06_03_04_06.csv
# Grouped by ['model_name', 'gen_mode'] and combined Meta-Llama-3-70B-Instruct_no_afterlines_DoubleVectorTester_06_03_17_33.csv, Meta-Llama-3-70B-Instruct_no_afterlines_DoubleMatrixTester_06_03_17_33.csv, Meta-Llama-3-70B-Instruct_no_afterlines_MTreeTester_06_03_17_33.csv, Meta-Llama-3-70B-Instruct_no_afterlines_SparseArrayTester_06_03_17_33.csv, Meta-Llama-3-70B-Instruct_no_afterlines_TopKTester_06_03_17_32.csv, Meta-Llama-3-70B-Instruct_no_afterlines_RNGTester_06_03_17_33.csv, Meta-Llama-3-70B-Instruct_no_afterlines_CounterTester_06_03_17_33.csv, Meta-Llama-3-70B-Instruct_no_afterlines_FactorizationTester_06_03_17_33.csv
# Grouped by ['model_name', 'gen_mode'] and combined phi-3-mini-4k_no_afterlines_DoubleMatrixTester_06_03_03_59.csv, phi-3-mini-4k_no_afterlines_DoubleVectorTester_06_03_04_04.csv, phi-3-mini-4k_no_afterlines_SparseArrayTester_06_03_04_00.csv, phi-3-mini-4k_no_afterlines_CounterTester_06_03_04_03.csv, phi-3-mini-4k_no_afterlines_RNGTester_06_03_04_02.csv, phi-3-mini-4k_no_afterlines_FactorizationTester_06_03_04_04.csv, phi-3-mini-4k_no_afterlines_MTreeTester_06_03_04_06.csv, phi-3-mini-4k_no_afterlines_TopKTester_06_03_03_58.csv
# Grouped by ['model_name', 'gen_mode'] and combined gpt-3.5-turbo-0125_no_afterlines_DoubleVectorTester_06_03_04_02.csv, gpt-3.5-turbo-0125_no_afterlines_DoubleMatrixTester_06_03_04_04.csv, gpt-3.5-turbo-0125_no_afterlines_TopKTester_06_03_04_03.csv, gpt-3.5-turbo-0125_no_afterlines_MTreeTester_06_03_04_01.csv, gpt-3.5-turbo-0125_no_afterlines_FactorizationTester_06_03_04_02.csv, gpt-3.5-turbo-0125_no_afterlines_RNGTester_06_03_04_01.csv, gpt-3.5-turbo-0125_no_afterlines_SparseArrayTester_06_03_03_59.csv, gpt-3.5-turbo-0125_no_afterlines_CounterTester_06_03_04_03.csv
# Grouped by ['model_name', 'gen_mode'] and combined claude-3-opus-20240229_no_afterlines_MTreeTester_06_03_04_05.csv, claude-3-opus-20240229_no_afterlines_RNGTester_06_03_04_03.csv, claude-3-opus-20240229_no_afterlines_DoubleMatrixTester_06_03_04_00.csv, claude-3-opus-20240229_no_afterlines_DoubleVectorTester_06_03_04_06.csv, claude-3-opus-20240229_no_afterlines_FactorizationTester_06_03_03_58.csv, claude-3-opus-20240229_no_afterlines_TopKTester_06_03_04_00.csv, claude-3-opus-20240229_no_afterlines_SparseArrayTester_06_03_04_06.csv, claude-3-opus-20240229_no_afterlines_CounterTester_06_03_04_02.csv
# Grouped by ['model_name', 'gen_mode'] and combined deepseek-coder-7b-instruct_no_afterlines_TopKTester_06_03_04_02.csv, deepseek-coder-7b-instruct_no_afterlines_SparseArrayTester_06_03_04_03.csv, deepseek-coder-7b-instruct_no_afterlines_DoubleVectorTester_06_03_03_59.csv, deepseek-coder-7b-instruct_no_afterlines_CounterTester_06_03_04_00.csv, deepseek-coder-7b-instruct_no_afterlines_RNGTester_06_03_04_04.csv, deepseek-coder-7b-instruct_no_afterlines_FactorizationTester_06_03_04_03.csv, deepseek-coder-7b-instruct_no_afterlines_DoubleMatrixTester_06_03_04_01.csv, deepseek-coder-7b-instruct_no_afterlines_MTreeTester_06_03_03_58.csv
# #############################################
# Original DataFrame: 286 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 8
# Rows after expansion: 1274 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1274 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 286 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 8
# Rows after expansion: 1274 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1274 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 286 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 8
# Rows after expansion: 1274 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1274 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 286 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 8
# Rows after expansion: 1274 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1274 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 286 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 8
# Rows after expansion: 1274 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1274 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 286 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 8
# Rows after expansion: 1274 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1274 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 286 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 8
# Rows after expansion: 1274 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1274 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 286 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 8
# Rows after expansion: 1274 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1274 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 286 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 8
# Rows after expansion: 1274 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1274 rows
# DataFrame after groupby: 278 rows
# #############################################
# Original DataFrame: 286 rows
# Rows dropped due to NaN in initial columns ['horizon_categories_output', 'horizon_freq_analysis']: 8
# Rows after expansion: 1274 rows
# Rows dropped due to NaN in additional columns ['horizon_categories_output', 'horizon_freq_analysis', 'Type', 'usage_line', 'def_line', 'abs_diff', 'post_process_pass_ratio']: 0
# Original DataFrame: 1274 rows
# DataFrame after groupby: 278 rows
# ################ Analyzing gpt-4-turbo_no_afterlines ################
# Number of rows with NaN values in 'comment_dist': 0
#       start_line  end_line      code_task  \
# 465           76        77  CounterTester
# 468           79        80  CounterTester
# 471          107       111  CounterTester
# 479          116       117  CounterTester
# 489          150       156  CounterTester
# ...          ...       ...            ...
# 1005         541       541     TopKTester
# 1007         559       559     TopKTester
# 1009         566       566     TopKTester
# 1012         568       568     TopKTester
# 1014         573       573     TopKTester
#
#                                                  before  \
# 465   ['import junit.framework.TestCase;', 'import j...
# 468   ['import junit.framework.TestCase;', 'import j...
# 471   ['import junit.framework.TestCase;', 'import j...
# 479   ['import junit.framework.TestCase;', 'import j...
# 489   ['import junit.framework.TestCase;', 'import j...
# ...                                                 ...
# 1005  ['import junit.framework.TestCase;', 'import j...
# 1007  ['import junit.framework.TestCase;', 'import j...
# 1009  ['import junit.framework.TestCase;', 'import j...
# 1012  ['import junit.framework.TestCase;', 'import j...
# 1014  ['import junit.framework.TestCase;', 'import j...
#
#                                                 between  \
# 465   ['      return myWord.compareTo(w.myWord);', '...
# 468          ['    return w.myCount - myCount;', '  }']
# 471   ['      ones.remove (addMe);', '      WordWrap...
# 479   ['      WordWrapper temp = wordsIHaveSeen.get ...
# 489   ['      int which = extractedWords.size ();', ...
# ...                                                 ...
# 1005                          ['      k = numInserts;']
# 1007           ['      reverseOrNot = controlTest[1];']
# 1009          ['        list[i] = numInserts - 1 - i;']
# 1012                          ['        list[i] = i; ']
# 1014                          ['      shuffle (list);']
#
#                                                   after  \
# 465   ["    // If the counts are not equal, subtract...
# 468   ['}', '', '', '/**', ' * This class is used to...
# 471   ['', '    // first check to see if the word is...
# 479   ['', '      // find the slot that we go to in ...
# 489   ['    } else {', '      // If k is less than t...
# ...                                                 ...
# 1005  ['    ', '    // make sure the list is the rig...
# 1007  ['    ', '    // create a list of random ints'...
# 1009  ['      else', '        list[i] = i; ', '    }...
# 1012  ['    }', '    ', '    // if we are looking fo...
# 1014  ['    ', '    // now add the ints', '    for (...
#
#                                           gen_code_dict  \
# 465   {'original_code': 'return myWord.compareTo(w.m...
# 468   {'original_code': 'return myCount - w.myCount;...
# 471   {'original_code': 'WordWrapper existing = word...
# 479   {'original_code': 'WordWrapper existing = word...
# 489   {'original_code': 'return null;', 'cleaned_cod...
# ...                                                 ...
# 1005  {'original_code': 'k = numInserts; \n\nfor (in...
# 1007  {'original_code': 'reverseOrNot = controlTest[...
# 1009  {'original_code': '        list[i] = numInsert...
# 1012  {'original_code': '        list[i] = i; \n    ...
# 1014  {'original_code': 'shuffle(list);', 'cleaned_c...
#
#                                  gen_code_process_steps  \
# 465   ['cleaned_code', 'trimmed_code', 'indented_code']
# 468   ['cleaned_code', 'trimmed_code', 'indented_code']
# 471   ['cleaned_code', 'trimmed_code', 'indented_code']
# 479   ['cleaned_code', 'trimmed_code', 'indented_code']
# 489   ['cleaned_code', 'trimmed_code', 'indented_code']
# ...                                                 ...
# 1005  ['cleaned_code', 'trimmed_code', 'indented_code']
# 1007  ['cleaned_code', 'trimmed_code', 'indented_code']
# 1009  ['cleaned_code', 'trimmed_code', 'indented_code']
# 1012  ['cleaned_code', 'trimmed_code', 'indented_code']
# 1014  ['cleaned_code', 'trimmed_code', 'indented_code']
#
#      selected_last_post_process_step  \
# 465                     cleaned_code
# 468                     cleaned_code
# 471                     cleaned_code
# 479                     cleaned_code
# 489                     cleaned_code
# ...                              ...
# 1005                    cleaned_code
# 1007                    cleaned_code
# 1009                    cleaned_code
# 1012                    cleaned_code
# 1014                    cleaned_code
#
#                                       gen_code_selected  ...  \
# 465   ['return myWord.compareTo(w.myWord);', '    }'...  ...
# 468                     ['return myCount - w.myCount;']  ...
# 471   ['WordWrapper existing = wordsIHaveSeen.get(ad...  ...
# 479   ['WordWrapper existing = wordsIHaveSeen.get(ad...  ...
# 489                                    ['return null;']  ...
# ...                                                 ...  ...
# 1005  ['k = numInserts; ', 'for (int i = 0; i < k; i...  ...
# 1007  ['reverseOrNot = controlTest[1];', '    ITopKM...  ...
# 1009  ['        list[i] = numInserts - 1 - i;', '   ...  ...
# 1012                 ['        list[i] = i; ', '    }']  ...
# 1014                                 ['shuffle(list);']  ...
#
#                                   post_process_eval_res  \
# 465   ['Success: Final output matches the expected r...
# 468                                         ['Error: ']
# 471                                         ['Error: ']
# 479   ['Error: Compilation error: /tmp/tmpjuonmgzd/C...
# 489                                         ['Error: ']
# ...                                                 ...
# 1005  ['Success: Final output matches the expected r...
# 1007  ['Success: Final output matches the expected r...
# 1009  ['Success: Final output matches the expected r...
# 1012  ['Error: Compilation error: /tmp/tmpkcemi5jr/T...
# 1014  ['Success: Final output matches the expected r...
#
#      post_process_pass_ratio  \
# 465                      1.0
# 468                      0.0
# 471                      0.0
# 479                      0.0
# 489                      0.0
# ...                      ...
# 1005                     1.0
# 1007                     1.0
# 1009                     1.0
# 1012                     0.0
# 1014                     1.0
#
#                                  2nd_post_process_steps             Type  \
# 465                                       indented_code  Global_Variable
# 468                                       indented_code  Global_Variable
# 471                                       indented_code            Class
# 479                                       indented_code            Class
# 489                                       indented_code  Global_Variable
# ...                                                 ...              ...
# 1005  ['cleaned_code', 'trimmed_code', 'indented_code']         Variable
# 1007                                       trimmed_code         Variable
# 1009                                       trimmed_code         Variable
# 1012                                      indented_code         Variable
# 1014  ['cleaned_code', 'trimmed_code', 'indented_code']         Function
#
#      usage_line def_line abs_diff  \
# 465          76       13       63
# 468          79       14       65
# 471         108       11       97
# 479         116       11      105
# 489         151       94       57
# ...         ...      ...      ...
# 1005        541      481       60
# 1007        559      553        6
# 1009        566      553       13
# 1012        568      564        4
# 1014        573      466      107
#
#                                          list_of_tuples comment_dist  \
# 465   [(76, 74), (79, 78), (107, 104), (116, 115), (...            2
# 468   [(76, 74), (79, 78), (107, 104), (116, 115), (...            1
# 471   [(76, 74), (79, 78), (107, 104), (116, 115), (...            3
# 479   [(76, 74), (79, 78), (107, 104), (116, 115), (...            1
# 489   [(76, 74), (79, 78), (107, 104), (116, 115), (...            2
# ...                                                 ...          ...
# 1005  [(167, 23), (190, 189), (212, 189), (215, 189)...            2
# 1007  [(167, 23), (190, 189), (212, 189), (215, 189)...            4
# 1009  [(167, 23), (190, 189), (212, 189), (215, 189)...            5
# 1012  [(167, 23), (190, 189), (212, 189), (215, 189)...            7
# 1014  [(167, 23), (190, 189), (212, 189), (215, 189)...            2
#
#       range_class
# 465         Short
# 468         Short
# 471         Short
# 479         Short
# 489         Short
# ...           ...
# 1005        Short
# 1007        Short
# 1009        Short
# 1012        Short
# 1014        Short
#
# [278 rows x 28 columns]
# ################ Analyzing Meta-Llama-3-8B-Instruct_no_afterlines ################
# Number of rows with NaN values in 'comment_dist': 0
#      start_line  end_line      code_task  \
# 637          76        77  CounterTester
# 640          79        80  CounterTester
# 643         107       111  CounterTester
# 651         116       117  CounterTester
# 661         150       156  CounterTester
# ..          ...       ...            ...
# 158         541       541     TopKTester
# 160         559       559     TopKTester
# 162         566       566     TopKTester
# 165         568       568     TopKTester
# 167         573       573     TopKTester
#
#                                                 before  \
# 637  ['import junit.framework.TestCase;', 'import j...
# 640  ['import junit.framework.TestCase;', 'import j...
# 643  ['import junit.framework.TestCase;', 'import j...
# 651  ['import junit.framework.TestCase;', 'import j...
# 661  ['import junit.framework.TestCase;', 'import j...
# ..                                                 ...
# 158  ['import junit.framework.TestCase;', 'import j...
# 160  ['import junit.framework.TestCase;', 'import j...
# 162  ['import junit.framework.TestCase;', 'import j...
# 165  ['import junit.framework.TestCase;', 'import j...
# 167  ['import junit.framework.TestCase;', 'import j...
#
#                                                between  \
# 637  ['      return myWord.compareTo(w.myWord);', '...
# 640         ['    return w.myCount - myCount;', '  }']
# 643  ['      ones.remove (addMe);', '      WordWrap...
# 651  ['      WordWrapper temp = wordsIHaveSeen.get ...
# 661  ['      int which = extractedWords.size ();', ...
# ..                                                 ...
# 158                          ['      k = numInserts;']
# 160           ['      reverseOrNot = controlTest[1];']
# 162          ['        list[i] = numInserts - 1 - i;']
# 165                          ['        list[i] = i; ']
# 167                          ['      shuffle (list);']
#
#                                                  after  \
# 637  ["    // If the counts are not equal, subtract...
# 640  ['}', '', '', '/**', ' * This class is used to...
# 643  ['', '    // first check to see if the word is...
# 651  ['', '      // find the slot that we go to in ...
# 661  ['    } else {', '      // If k is less than t...
# ..                                                 ...
# 158  ['    ', '    // make sure the list is the rig...
# 160  ['    ', '    // create a list of random ints'...
# 162  ['      else', '        list[i] = i; ', '    }...
# 165  ['    }', '    ', '    // if we are looking fo...
# 167  ['    ', '    // now add the ints', '    for (...
#
#                                          gen_code_dict  \
# 637  {'original_code': "Here is the Java code to co...
# 640  {'original_code': "Here is the completed Java ...
# 643  {'original_code': 'Here is the completed Java ...
# 651  {'original_code': 'public void insert(String a...
# 661  {'original_code': 'public String getKthMostFre...
# ..                                                 ...
# 158  {'original_code': 'Here is the completed Java ...
# 160  {'original_code': 'Here is the completed Java ...
# 162  {'original_code': 'Here is the completed Java ...
# 165  {'original_code': 'Here is the completed Java ...
# 167  {'original_code': 'Here is the completed Java ...
#
#                                 gen_code_process_steps  \
# 637  ['cleaned_code', 'trimmed_code', 'indented_code']
# 640  ['cleaned_code', 'trimmed_code', 'indented_code']
# 643  ['cleaned_code', 'trimmed_code', 'indented_code']
# 651  ['cleaned_code', 'trimmed_code', 'indented_code']
# 661  ['cleaned_code', 'trimmed_code', 'indented_code']
# ..                                                 ...
# 158  ['cleaned_code', 'trimmed_code', 'indented_code']
# 160  ['cleaned_code', 'trimmed_code', 'indented_code']
# 162  ['cleaned_code', 'trimmed_code', 'indented_code']
# 165  ['cleaned_code', 'trimmed_code', 'indented_code']
# 167  ['cleaned_code', 'trimmed_code', 'indented_code']
#
#     selected_last_post_process_step  \
# 637                    cleaned_code
# 640                    cleaned_code
# 643                    cleaned_code
# 651                    cleaned_code
# 661                    cleaned_code
# ..                              ...
# 158                    cleaned_code
# 160                    cleaned_code
# 162                    cleaned_code
# 165                    cleaned_code
# 167                    cleaned_code
#
#                                      gen_code_selected  ...  \
# 637  ['public int compareTo(WordWrapper w) {', '   ...  ...
# 640  ['public int compareTo(WordWrapper w) {', '   ...  ...
# 643  ['public void insert(String addMe) {', '    if...  ...
# 651  ['public void insert(String addMe) {', '    if...  ...
# 661  ['public String getKthMostFrequent(int k) {', ...  ...
# ..                                                 ...  ...
# 158  ['public void testInserts(int numInserts, int ...  ...
# 160  ['public void testInserts(int numInserts, int ...  ...
# 162  ['public void testInserts(int numInserts, int ...  ...
# 165  ['public void testBalance(int numInserts, int ...  ...
# 167             ['', 'testBalance(100, 5, true);', '']  ...
#
#                                  post_process_eval_res  \
# 637                                        ['Error: ']
# 640  ['Error: Compilation error: /tmp/tmpksxey74g/C...
# 643  ['Error: Problem reading file\njava.lang.NullP...
# 651  ['Error: Compilation error: /tmp/tmpec4a2vlr/C...
# 661                                        ['Error: ']
# ..                                                 ...
# 158  ['Error: Compilation error: /tmp/tmp1ugabl0_/T...
# 160  ['Error: Compilation error: /tmp/tmptyazdq_m/T...
# 162  ['Success: Final output matches the expected r...
# 165  ['Success: Final output matches the expected r...
# 167                                        ['Error: ']
#
#     post_process_pass_ratio  2nd_post_process_steps             Type  \
# 637                     0.0           indented_code  Global_Variable
# 640                     0.0           indented_code  Global_Variable
# 643                     0.0           indented_code            Class
# 651                     0.0           indented_code            Class
# 661                     0.0           indented_code  Global_Variable
# ..                      ...                     ...              ...
# 158                     0.0           indented_code         Variable
# 160                     0.0           indented_code         Variable
# 162                     1.0            trimmed_code         Variable
# 165                     1.0           indented_code         Variable
# 167                     0.0           indented_code         Function
#
#     usage_line def_line abs_diff  \
# 637         76       13       63
# 640         79       14       65
# 643        108       11       97
# 651        116       11      105
# 661        151       94       57
# ..         ...      ...      ...
# 158        541      481       60
# 160        559      553        6
# 162        566      553       13
# 165        568      564        4
# 167        573      466      107
#
#                                         list_of_tuples comment_dist  \
# 637  [(76, 74), (79, 78), (107, 104), (116, 115), (...            2
# 640  [(76, 74), (79, 78), (107, 104), (116, 115), (...            1
# 643  [(76, 74), (79, 78), (107, 104), (116, 115), (...            3
# 651  [(76, 74), (79, 78), (107, 104), (116, 115), (...            1
# 661  [(76, 74), (79, 78), (107, 104), (116, 115), (...            2
# ..                                                 ...          ...
# 158  [(167, 23), (190, 189), (212, 189), (215, 189)...            2
# 160  [(167, 23), (190, 189), (212, 189), (215, 189)...            4
# 162  [(167, 23), (190, 189), (212, 189), (215, 189)...            5
# 165  [(167, 23), (190, 189), (212, 189), (215, 189)...            7
# 167  [(167, 23), (190, 189), (212, 189), (215, 189)...            2
#
#      range_class
# 637        Short
# 640        Short
# 643        Short
# 651        Short
# 661        Short
# ..           ...
# 158        Short
# 160        Short
# 162        Short
# 165        Short
# 167        Short
#
# [278 rows x 28 columns]
# ################ Analyzing claude-3-sonnet-20240229_no_afterlines ################
# Number of rows with NaN values in 'comment_dist': 0
#       start_line  end_line      code_task  \
# 1076          76        77  CounterTester
# 1079          79        80  CounterTester
# 1082         107       111  CounterTester
# 1090         116       117  CounterTester
# 1100         150       156  CounterTester
# ...          ...       ...            ...
# 738          541       541     TopKTester
# 740          559       559     TopKTester
# 742          566       566     TopKTester
# 745          568       568     TopKTester
# 747          573       573     TopKTester
#
#                                                  before  \
# 1076  ['import junit.framework.TestCase;', 'import j...
# 1079  ['import junit.framework.TestCase;', 'import j...
# 1082  ['import junit.framework.TestCase;', 'import j...
# 1090  ['import junit.framework.TestCase;', 'import j...
# 1100  ['import junit.framework.TestCase;', 'import j...
# ...                                                 ...
# 738   ['import junit.framework.TestCase;', 'import j...
# 740   ['import junit.framework.TestCase;', 'import j...
# 742   ['import junit.framework.TestCase;', 'import j...
# 745   ['import junit.framework.TestCase;', 'import j...
# 747   ['import junit.framework.TestCase;', 'import j...
#
#                                                 between  \
# 1076  ['      return myWord.compareTo(w.myWord);', '...
# 1079         ['    return w.myCount - myCount;', '  }']
# 1082  ['      ones.remove (addMe);', '      WordWrap...
# 1090  ['      WordWrapper temp = wordsIHaveSeen.get ...
# 1100  ['      int which = extractedWords.size ();', ...
# ...                                                 ...
# 738                           ['      k = numInserts;']
# 740            ['      reverseOrNot = controlTest[1];']
# 742           ['        list[i] = numInserts - 1 - i;']
# 745                           ['        list[i] = i; ']
# 747                           ['      shuffle (list);']
#
#                                                   after  \
# 1076  ["    // If the counts are not equal, subtract...
# 1079  ['}', '', '', '/**', ' * This class is used to...
# 1082  ['', '    // first check to see if the word is...
# 1090  ['', '      // find the slot that we go to in ...
# 1100  ['    } else {', '      // If k is less than t...
# ...                                                 ...
# 738   ['    ', '    // make sure the list is the rig...
# 740   ['    ', '    // create a list of random ints'...
# 742   ['      else', '        list[i] = i; ', '    }...
# 745   ['    }', '    ', '    // if we are looking fo...
# 747   ['    ', '    // now add the ints', '    for (...
#
#                                           gen_code_dict  \
# 1076  {'original_code': '# --BEGIN MISSING CODE--\n ...
# 1079  {'original_code': '# --BEGIN MISSING CODE--\nr...
# 1082  {'original_code': '# --BEGIN MISSING CODE--\n ...
# 1090  {'original_code': '# --BEGIN MISSING CODE--\n ...
# 1100  {'original_code': '# --BEGIN MISSING CODE--\n ...
# ...                                                 ...
# 738   {'original_code': '# --BEGIN MISSING CODE--\n ...
# 740   {'original_code': '# --BEGIN MISSING CODE--\n ...
# 742   {'original_code': '# --BEGIN MISSING CODE--\n ...
# 745   {'original_code': '# --BEGIN MISSING CODE--\n ...
# 747   {'original_code': '# --BEGIN MISSING CODE--\ns...
#
#                                  gen_code_process_steps  \
# 1076  ['cleaned_code', 'trimmed_code', 'indented_code']
# 1079  ['cleaned_code', 'trimmed_code', 'indented_code']
# 1082  ['cleaned_code', 'trimmed_code', 'indented_code']
# 1090  ['cleaned_code', 'trimmed_code', 'indented_code']
# 1100  ['cleaned_code', 'trimmed_code', 'indented_code']
# ...                                                 ...
# 738   ['cleaned_code', 'trimmed_code', 'indented_code']
# 740   ['cleaned_code', 'trimmed_code', 'indented_code']
# 742   ['cleaned_code', 'trimmed_code', 'indented_code']
# 745   ['cleaned_code', 'trimmed_code', 'indented_code']
# 747   ['cleaned_code', 'trimmed_code', 'indented_code']
#
#      selected_last_post_process_step  \
# 1076                    cleaned_code
# 1079                    cleaned_code
# 1082                    cleaned_code
# 1090                    cleaned_code
# 1100                    cleaned_code
# ...                              ...
# 738                     cleaned_code
# 740                     cleaned_code
# 742                     cleaned_code
# 745                     cleaned_code
# 747                     cleaned_code
#
#                                       gen_code_selected  ...  \
# 1076  ['      return myWord.compareTo(w.myWord);', '...  ...
# 1079                    ['return w.myCount - myCount;']  ...
# 1082  ['      WordWrapper temp = wordsIHaveSeen.get(...  ...
# 1090  ['      WordWrapper temp = wordsIHaveSeen.get(...  ...
# 1100  ['      return null;', '    } else {', '      ...  ...
# ...                                                 ...  ...
# 738   ['    k = numInserts;', 'for (int i = 0; i < k...  ...
# 740   ['      reverseOrNot = controlTest[1];', '    ...  ...
# 742   ['        list[i] = numInserts - 1 - i;', '   ...  ...
# 745   ['        list[i] = i;', '    }', '    if (ran...  ...
# 747   ['shuffle (list);', 'for (int j = 0; j < list....  ...
#
#                                   post_process_eval_res  \
# 1076  ['Success: Final output matches the expected r...
# 1079  ['Success: Final output matches the expected r...
# 1082  ['Error: Problem reading file\njava.lang.NullP...
# 1090  ['Success: Final output matches the expected r...
# 1100                                        ['Error: ']
# ...                                                 ...
# 738   ['Success: Final output matches the expected r...
# 740   ['Success: Final output matches the expected r...
# 742   ['Success: Final output matches the expected r...
# 745   ['Success: Final output matches the expected r...
# 747   ['Success: Final output matches the expected r...
#
#      post_process_pass_ratio  \
# 1076                     1.0
# 1079                     1.0
# 1082                     0.0
# 1090                     1.0
# 1100                     0.0
# ...                      ...
# 738                      1.0
# 740                      1.0
# 742                      1.0
# 745                      1.0
# 747                      1.0
#
#                                  2nd_post_process_steps             Type  \
# 1076                                      indented_code  Global_Variable
# 1079                                      indented_code  Global_Variable
# 1082                                      indented_code            Class
# 1090                                       trimmed_code            Class
# 1100                                      indented_code  Global_Variable
# ...                                                 ...              ...
# 738                                        trimmed_code         Variable
# 740                                        trimmed_code         Variable
# 742                                        trimmed_code         Variable
# 745                                        trimmed_code         Variable
# 747   ['cleaned_code', 'trimmed_code', 'indented_code']         Function
#
#      usage_line def_line abs_diff  \
# 1076         76       13       63
# 1079         79       14       65
# 1082        108       11       97
# 1090        116       11      105
# 1100        151       94       57
# ...         ...      ...      ...
# 738         541      481       60
# 740         559      553        6
# 742         566      553       13
# 745         568      564        4
# 747         573      466      107
#
#                                          list_of_tuples comment_dist  \
# 1076  [(76, 74), (79, 78), (107, 104), (116, 115), (...            2
# 1079  [(76, 74), (79, 78), (107, 104), (116, 115), (...            1
# 1082  [(76, 74), (79, 78), (107, 104), (116, 115), (...            3
# 1090  [(76, 74), (79, 78), (107, 104), (116, 115), (...            1
# 1100  [(76, 74), (79, 78), (107, 104), (116, 115), (...            2
# ...                                                 ...          ...
# 738   [(167, 23), (190, 189), (212, 189), (215, 189)...            2
# 740   [(167, 23), (190, 189), (212, 189), (215, 189)...            4
# 742   [(167, 23), (190, 189), (212, 189), (215, 189)...            5
# 745   [(167, 23), (190, 189), (212, 189), (215, 189)...            7
# 747   [(167, 23), (190, 189), (212, 189), (215, 189)...            2
#
#       range_class
# 1076        Short
# 1079        Short
# 1082        Short
# 1090        Short
# 1100        Short
# ...           ...
# 738         Short
# 740         Short
# 742         Short
# 745         Short
# 747         Short
#
# [278 rows x 28 columns]
# ################ Analyzing deepseek-coder-1.3b-instruct_no_afterlines ################
# Number of rows with NaN values in 'comment_dist': 0
#      start_line  end_line      code_task  \
# 258          76        77  CounterTester
# 261          79        80  CounterTester
# 264         107       111  CounterTester
# 272         116       117  CounterTester
# 282         150       156  CounterTester
# ..          ...       ...            ...
# 473         541       541     TopKTester
# 475         559       559     TopKTester
# 477         566       566     TopKTester
# 480         568       568     TopKTester
# 482         573       573     TopKTester
#
#                                                 before  \
# 258  ['import junit.framework.TestCase;', 'import j...
# 261  ['import junit.framework.TestCase;', 'import j...
# 264  ['import junit.framework.TestCase;', 'import j...
# 272  ['import junit.framework.TestCase;', 'import j...
# 282  ['import junit.framework.TestCase;', 'import j...
# ..                                                 ...
# 473  ['import junit.framework.TestCase;', 'import j...
# 475  ['import junit.framework.TestCase;', 'import j...
# 477  ['import junit.framework.TestCase;', 'import j...
# 480  ['import junit.framework.TestCase;', 'import j...
# 482  ['import junit.framework.TestCase;', 'import j...
#
#                                                between  \
# 258  ['      return myWord.compareTo(w.myWord);', '...
# 261         ['    return w.myCount - myCount;', '  }']
# 264  ['      ones.remove (addMe);', '      WordWrap...
# 272  ['      WordWrapper temp = wordsIHaveSeen.get ...
# 282  ['      int which = extractedWords.size ();', ...
# ..                                                 ...
# 473                          ['      k = numInserts;']
# 475           ['      reverseOrNot = controlTest[1];']
# 477          ['        list[i] = numInserts - 1 - i;']
# 480                          ['        list[i] = i; ']
# 482                          ['      shuffle (list);']
#
#                                                  after  \
# 258  ["    // If the counts are not equal, subtract...
# 261  ['}', '', '', '/**', ' * This class is used to...
# 264  ['', '    // first check to see if the word is...
# 272  ['', '      // find the slot that we go to in ...
# 282  ['    } else {', '      // If k is less than t...
# ..                                                 ...
# 473  ['    ', '    // make sure the list is the rig...
# 475  ['    ', '    // create a list of random ints'...
# 477  ['      else', '        list[i] = i; ', '    }...
# 480  ['    }', '    ', '    // if we are looking fo...
# 482  ['    ', '    // now add the ints', '    for (...
#
#                                          gen_code_dict  \
# 258  {'original_code': 'The missing code is as foll...
# 261  {'original_code': "Here is the missing code:\n...
# 264  {'original_code': 'The missing code is as foll...
# 272  {'original_code': 'The missing code is as foll...
# 282  {'original_code': 'Here is the complete Java c...
# ..                                                 ...
# 473  {'original_code': 'The missing code is as foll...
# 475  {'original_code': 'The code provided is incomp...
# 477  {'original_code': 'The code you provided is in...
# 480  {'original_code': 'The missing code is:\n\n```...
# 482  {'original_code': 'The code provided is incomp...
#
#                                 gen_code_process_steps  \
# 258  ['cleaned_code', 'trimmed_code', 'indented_code']
# 261  ['cleaned_code', 'trimmed_code', 'indented_code']
# 264  ['cleaned_code', 'trimmed_code', 'indented_code']
# 272  ['cleaned_code', 'trimmed_code', 'indented_code']
# 282  ['cleaned_code', 'trimmed_code', 'indented_code']
# ..                                                 ...
# 473  ['cleaned_code', 'trimmed_code', 'indented_code']
# 475  ['cleaned_code', 'trimmed_code', 'indented_code']
# 477  ['cleaned_code', 'trimmed_code', 'indented_code']
# 480  ['cleaned_code', 'trimmed_code', 'indented_code']
# 482  ['cleaned_code', 'trimmed_code', 'indented_code']
#
#     selected_last_post_process_step  \
# 258                    cleaned_code
# 261                    cleaned_code
# 264                    cleaned_code
# 272                    cleaned_code
# 282                    cleaned_code
# ..                              ...
# 473                    cleaned_code
# 475                    cleaned_code
# 477                    cleaned_code
# 480                    cleaned_code
# 482                    cleaned_code
#
#                                      gen_code_selected  ...  \
# 258  ['', '    return w.myWord.compareTo(myWord);',...  ...
# 261  ['', '    return w.myCount - myCount;', '}', '...  ...
# 264  ['      WordWrapper existingWord = wordsIHaveS...  ...
# 272  ['', '      wordsIHaveSeen.get(addMe).incCount...  ...
# 282  ['class WordWrapper implements Comparable<Word...  ...
# ..                                                 ...  ...
# 473  ['', '// --END MISSING CODE--', '    ArrayList...  ...
# 475  ['public class AVLNode <T> {', '    Data <T> v...  ...
# 477  ['public class AVLNode <T> {', '  T val;', '  ...  ...
# 480  ['', '// --END MISSING CODE--', '    }', '    ...  ...
# 482  ['public void testBalance(int numInserts, int ...  ...
#
#                                  post_process_eval_res  \
# 258                                        ['Error: ']
# 261  ['Success: Final output matches the expected r...
# 264                                        ['Error: ']
# 272  ['Error: Compilation error: /tmp/tmpbffexxnt/C...
# 282  ["Error: Compilation error: /tmp/tmp4uomf6rs/C...
# ..                                                 ...
# 473  ['Error: Compilation error: /tmp/tmp48ga32ee/T...
# 475  ["Error: Compilation error: /tmp/tmpop7y_sn0/T...
# 477  ["Error: Compilation error: /tmp/tmpj2x_1dva/T...
# 480  ['Error: Compilation error: /tmp/tmp_j4hi1bk/T...
# 482  ['Error: Compilation error: /tmp/tmp4qg4ebrl/T...
#
#     post_process_pass_ratio  2nd_post_process_steps             Type  \
# 258                     0.0           indented_code  Global_Variable
# 261                     1.0           indented_code  Global_Variable
# 264                     0.0           indented_code            Class
# 272                     0.0           indented_code            Class
# 282                     0.0           indented_code  Global_Variable
# ..                      ...                     ...              ...
# 473                     0.0           indented_code         Variable
# 475                     0.0           indented_code         Variable
# 477                     0.0           indented_code         Variable
# 480                     0.0           indented_code         Variable
# 482                     0.0           indented_code         Function
#
#     usage_line def_line abs_diff  \
# 258         76       13       63
# 261         79       14       65
# 264        108       11       97
# 272        116       11      105
# 282        151       94       57
# ..         ...      ...      ...
# 473        541      481       60
# 475        559      553        6
# 477        566      553       13
# 480        568      564        4
# 482        573      466      107
#
#                                         list_of_tuples comment_dist  \
# 258  [(76, 74), (79, 78), (107, 104), (116, 115), (...            2
# 261  [(76, 74), (79, 78), (107, 104), (116, 115), (...            1
# 264  [(76, 74), (79, 78), (107, 104), (116, 115), (...            3
# 272  [(76, 74), (79, 78), (107, 104), (116, 115), (...            1
# 282  [(76, 74), (79, 78), (107, 104), (116, 115), (...            2
# ..                                                 ...          ...
# 473  [(167, 23), (190, 189), (212, 189), (215, 189)...            2
# 475  [(167, 23), (190, 189), (212, 189), (215, 189)...            4
# 477  [(167, 23), (190, 189), (212, 189), (215, 189)...            5
# 480  [(167, 23), (190, 189), (212, 189), (215, 189)...            7
# 482  [(167, 23), (190, 189), (212, 189), (215, 189)...            2
#
#      range_class
# 258        Short
# 261        Short
# 264        Short
# 272        Short
# 282        Short
# ..           ...
# 473        Short
# 475        Short
# 477        Short
# 480        Short
# 482        Short
#
# [278 rows x 28 columns]
# ################ Analyzing claude-3-haiku-20240307_no_afterlines ################
# Number of rows with NaN values in 'comment_dist': 0
#      start_line  end_line      code_task  \
# 666          76        77  CounterTester
# 669          79        80  CounterTester
# 672         107       111  CounterTester
# 680         116       117  CounterTester
# 690         150       156  CounterTester
# ..          ...       ...            ...
# 342         541       541     TopKTester
# 344         559       559     TopKTester
# 346         566       566     TopKTester
# 349         568       568     TopKTester
# 351         573       573     TopKTester
#
#                                                 before  \
# 666  ['import junit.framework.TestCase;', 'import j...
# 669  ['import junit.framework.TestCase;', 'import j...
# 672  ['import junit.framework.TestCase;', 'import j...
# 680  ['import junit.framework.TestCase;', 'import j...
# 690  ['import junit.framework.TestCase;', 'import j...
# ..                                                 ...
# 342  ['import junit.framework.TestCase;', 'import j...
# 344  ['import junit.framework.TestCase;', 'import j...
# 346  ['import junit.framework.TestCase;', 'import j...
# 349  ['import junit.framework.TestCase;', 'import j...
# 351  ['import junit.framework.TestCase;', 'import j...
#
#                                                between  \
# 666  ['      return myWord.compareTo(w.myWord);', '...
# 669         ['    return w.myCount - myCount;', '  }']
# 672  ['      ones.remove (addMe);', '      WordWrap...
# 680  ['      WordWrapper temp = wordsIHaveSeen.get ...
# 690  ['      int which = extractedWords.size ();', ...
# ..                                                 ...
# 342                          ['      k = numInserts;']
# 344           ['      reverseOrNot = controlTest[1];']
# 346          ['        list[i] = numInserts - 1 - i;']
# 349                          ['        list[i] = i; ']
# 351                          ['      shuffle (list);']
#
#                                                  after  \
# 666  ["    // If the counts are not equal, subtract...
# 669  ['}', '', '', '/**', ' * This class is used to...
# 672  ['', '    // first check to see if the word is...
# 680  ['', '      // find the slot that we go to in ...
# 690  ['    } else {', '      // If k is less than t...
# ...
# 1223  ['      ones.remove (addMe);', '      WordWrap...
# 1231  ['      WordWrapper temp = wordsIHaveSeen.get ...
# 1241  ['      int which = extractedWords.size ();', ...
# ...                                                 ...
# 1151                          ['      k = numInserts;']
# 1153           ['      reverseOrNot = controlTest[1];']
# 1155          ['        list[i] = numInserts - 1 - i;']
# 1158                          ['        list[i] = i; ']
# 1160                          ['      shuffle (list);']
#
#                                                   after  \
# 1217  ["    // If the counts are not equal, subtract...
# 1220  ['}', '', '', '/**', ' * This class is used to...
# 1223  ['', '    // first check to see if the word is...
# 1231  ['', '      // find the slot that we go to in ...
# 1241  ['    } else {', '      // If k is less than t...
# ...                                                 ...
# 1151  ['    ', '    // make sure the list is the rig...
# 1153  ['    ', '    // create a list of random ints'...
# 1155  ['      else', '        list[i] = i; ', '    }...
# 1158  ['    }', '    ', '    // if we are looking fo...
# 1160  ['    ', '    // now add the ints', '    for (...
#
#                                           gen_code_dict  \
# 1217  {'original_code': 'Here is the generated code ...
# 1220  {'original_code': 'Here is the missing code to...
# 1223  {'original_code': 'Here is the generated code ...
# 1231  {'original_code': 'Here is the generated code ...
# 1241  {'original_code': 'Here is the generated code ...
# ...                                                 ...
# 1151  {'original_code': 'Here is the missing Java co...
# 1153  {'original_code': 'Here is the missing code to...
# 1155  {'original_code': 'Here is the missing code to...
# 1158  {'original_code': 'Here is the missing code to...
# 1160  {'original_code': 'Here is the missing code to...
#
#                                  gen_code_process_steps  \
# 1217  ['cleaned_code', 'trimmed_code', 'indented_code']
# 1220  ['cleaned_code', 'trimmed_code', 'indented_code']
# 1223  ['cleaned_code', 'trimmed_code', 'indented_code']
# 1231  ['cleaned_code', 'trimmed_code', 'indented_code']
# 1241  ['cleaned_code', 'trimmed_code', 'indented_code']
# ...                                                 ...
# 1151  ['cleaned_code', 'trimmed_code', 'indented_code']
# 1153  ['cleaned_code', 'trimmed_code', 'indented_code']
# 1155  ['cleaned_code', 'trimmed_code', 'indented_code']
# 1158  ['cleaned_code', 'trimmed_code', 'indented_code']
# 1160  ['cleaned_code', 'trimmed_code', 'indented_code']
#
#      selected_last_post_process_step  \
# 1217                    cleaned_code
# 1220                    cleaned_code
# 1223                    cleaned_code
# 1231                    cleaned_code
# 1241                    cleaned_code
# ...                              ...
# 1151                    cleaned_code
# 1153                    cleaned_code
# 1155                    cleaned_code
# 1158                    cleaned_code
# 1160                    cleaned_code
#
#                                       gen_code_selected  ...  \
# 1217  ['      return myWord.compareTo(w.myWord);', '...  ...
# 1220         ['    return w.myCount - myCount;', '  }']  ...
# 1223  ['    }', '    ones.put (addMe, addMe);', '   ...  ...
# 1231  ['      WordWrapper temp = wordsIHaveSeen.get ...  ...
# 1241  ['      return null;', '    }', '    return ex...  ...
# ...                                                 ...  ...
# 1151  ['      k = numInserts;', '    for (int i = 0;...  ...
# 1153           ['      reverseOrNot = controlTest[1];']  ...
# 1155  ['        list[i] = numInserts - 1 - i;', '   ...  ...
# 1158  ['        list[i] = i; ', '    }', '    if (ra...  ...
# 1160  ['      shuffle (list);', '    for (int j = 0;...  ...
#
#                                   post_process_eval_res  \
# 1217  ['Success: Final output matches the expected r...
# 1220  ['Success: Final output matches the expected r...
# 1223                                        ['Error: ']
# 1231  ["Error: Compilation error: /tmp/tmpymxkys4m/C...
# 1241                                        ['Error: ']
# ...                                                 ...
# 1151  ['Success: Final output matches the expected r...
# 1153  ['Success: Final output matches the expected r...
# 1155  ['Success: Final output matches the expected r...
# 1158  ['Success: Final output matches the expected r...
# 1160  ['Success: Final output matches the expected r...
#
#      post_process_pass_ratio  \
# 1217                     1.0
# 1220                     1.0
# 1223                     0.0
# 1231                     0.0
# 1241                     0.0
# ...                      ...
# 1151                     1.0
# 1153                     1.0
# 1155                     1.0
# 1158                     1.0
# 1160                     1.0
#
#                                  2nd_post_process_steps             Type  \
# 1217                                      indented_code  Global_Variable
# 1220  ['cleaned_code', 'trimmed_code', 'indented_code']  Global_Variable
# 1223                                      indented_code            Class
# 1231                                      indented_code            Class
# 1241                                      indented_code  Global_Variable
# ...                                                 ...              ...
# 1151                                       trimmed_code         Variable
# 1153  ['cleaned_code', 'trimmed_code', 'indented_code']         Variable
# 1155                                       trimmed_code         Variable
# 1158                                       trimmed_code         Variable
# 1160                                       trimmed_code         Function
#
#      usage_line def_line abs_diff  \
# 1217         76       13       63
# 1220         79       14       65
# 1223        108       11       97
# 1231        116       11      105
# 1241        151       94       57
# ...         ...      ...      ...
# 1151        541      481       60
# 1153        559      553        6
# 1155        566      553       13
# 1158        568      564        4
# 1160        573      466      107
#
#                                          list_of_tuples comment_dist  \
# 1217  [(76, 74), (79, 78), (107, 104), (116, 115), (...            2
# 1220  [(76, 74), (79, 78), (107, 104), (116, 115), (...            1
# 1223  [(76, 74), (79, 78), (107, 104), (116, 115), (...            3
# 1231  [(76, 74), (79, 78), (107, 104), (116, 115), (...            1
# 1241  [(76, 74), (79, 78), (107, 104), (116, 115), (...            2
# ...                                                 ...          ...
# 1151  [(167, 23), (190, 189), (212, 189), (215, 189)...            2
# 1153  [(167, 23), (190, 189), (212, 189), (215, 189)...            4
# 1155  [(167, 23), (190, 189), (212, 189), (215, 189)...            5
# 1158  [(167, 23), (190, 189), (212, 189), (215, 189)...            7
# 1160  [(167, 23), (190, 189), (212, 189), (215, 189)...            2
#
#       range_class
# 1217        Short
# 1220        Short
# 1223        Short
# 1231        Short
# 1241        Short
# ...           ...
# 1151        Short
# 1153        Short
# 1155        Short
# 1158        Short
# 1160        Short
#
# [278 rows x 28 columns]
# ################ Analyzing deepseek-coder-7b-instruct_no_afterlines ################
# Number of rows with NaN values in 'comment_dist': 0
#      start_line  end_line      code_task  \
# 365          76        77  CounterTester
# 368          79        80  CounterTester
# 371         107       111  CounterTester
# 379         116       117  CounterTester
# 389         150       156  CounterTester
# ..          ...       ...            ...
# 158         541       541     TopKTester
# 160         559       559     TopKTester
# 162         566       566     TopKTester
# 165         568       568     TopKTester
# 167         573       573     TopKTester
#
#                                                 before  \
# 365  ['import junit.framework.TestCase;', 'import j...
# 368  ['import junit.framework.TestCase;', 'import j...
# 371  ['import junit.framework.TestCase;', 'import j...
# 379  ['import junit.framework.TestCase;', 'import j...
# 389  ['import junit.framework.TestCase;', 'import j...
# ..                                                 ...
# 158  ['import junit.framework.TestCase;', 'import j...
# 160  ['import junit.framework.TestCase;', 'import j...
# 162  ['import junit.framework.TestCase;', 'import j...
# 165  ['import junit.framework.TestCase;', 'import j...
# 167  ['import junit.framework.TestCase;', 'import j...
#
#                                                between  \
# 365  ['      return myWord.compareTo(w.myWord);', '...
# 368         ['    return w.myCount - myCount;', '  }']
# 371  ['      ones.remove (addMe);', '      WordWrap...
# 379  ['      WordWrapper temp = wordsIHaveSeen.get ...
# 389  ['      int which = extractedWords.size ();', ...
# ..                                                 ...
# 158                          ['      k = numInserts;']
# 160           ['      reverseOrNot = controlTest[1];']
# 162          ['        list[i] = numInserts - 1 - i;']
# 165                          ['        list[i] = i; ']
# 167                          ['      shuffle (list);']
#
#                                                  after  \
# 365  ["    // If the counts are not equal, subtract...
# 368  ['}', '', '', '/**', ' * This class is used to...
# 371  ['', '    // first check to see if the word is...
# 379  ['', '      // find the slot that we go to in ...
# 389  ['    } else {', '      // If k is less than t...
# ..                                                 ...
# 158  ['    ', '    // make sure the list is the rig...
# 160  ['    ', '    // create a list of random ints'...
# 162  ['      else', '        list[i] = i; ', '    }...
# 165  ['    }', '    ', '    // if we are looking fo...
# 167  ['    ', '    // now add the ints', '    for (...
#
#                                          gen_code_dict  \
# 365  {'original_code': '```java\n      return myWor...
# 368  {'original_code': '```java\n    return myCount...
# 371  {'original_code': 'Here is the missing code:\n...
# 379  {'original_code': '```java\n      wordsIHaveSe...
# 389  {'original_code': '```java\n      return new S...
# ..                                                 ...
# 158  {'original_code': '```java\n    for (int i = 0...
# 160  {'original_code': '```java\n      reverseOrNot...
# 162  {'original_code': "```java\n        list[i] = ...
# 165  {'original_code': "```java\n        list[i] = ...
# 167  {'original_code': '```java\n      shuffle (lis...
#
#                                 gen_code_process_steps  \
# 365  ['cleaned_code', 'trimmed_code', 'indented_code']
# 368  ['cleaned_code', 'trimmed_code', 'indented_code']
# 371  ['cleaned_code', 'trimmed_code', 'indented_code']
# 379  ['cleaned_code', 'trimmed_code', 'indented_code']
# 389  ['cleaned_code', 'trimmed_code', 'indented_code']
# ..                                                 ...
# 158  ['cleaned_code', 'trimmed_code', 'indented_code']
# 160  ['cleaned_code', 'trimmed_code', 'indented_code']
# 162  ['cleaned_code', 'trimmed_code', 'indented_code']
# 165  ['cleaned_code', 'trimmed_code', 'indented_code']
# 167  ['cleaned_code', 'trimmed_code', 'indented_code']
#
#     selected_last_post_process_step  \
# 365                    cleaned_code
# 368                    cleaned_code
# 371                    cleaned_code
# 379                    cleaned_code
# 389                    cleaned_code
# ..                              ...
# 158                    cleaned_code
# 160                    cleaned_code
# 162                    cleaned_code
# 165                    cleaned_code
# 167                    cleaned_code
#
#                                      gen_code_selected  ...  \
# 365  ['', '      return myWord.compareTo(w.myWord);...  ...
# 368  ['', '    return myCount - w.myCount;', '  }',...  ...
# 371  ['', '      String existing = ones.get(addMe);...  ...
# 379  ['', '      wordsIHaveSeen.get(addMe).incCount...  ...
# 389  ['', '      return new String (extractedWords....  ...
# ..                                                 ...  ...
# 158  ['', '    for (int i = 0; i < k && i < retVal....  ...
# 160  ['      reverseOrNot = controlTest[1];', '    ...  ...
# 162  ['        list[i] = numInserts - 1 - i;', '   ...  ...
# 165  ['        list[i] = i; ', '      }', '    }', ...  ...
# 167  ['', '      shuffle (list);', '    }', '', '  ...  ...
#
#                                  post_process_eval_res  \
# 365  ['Error: Compilation error: /tmp/tmpvdx_hb1m/C...
# 368                                        ['Error: ']
# 371  ['Error: Problem reading file\njava.lang.NullP...
# 379  ['Error: Compilation error: /tmp/tmpbprubfnt/C...
# 389  ['Error: Compilation error: /tmp/tmpmfw3rb6v/C...
# ..                                                 ...
# 158                                        ['Error: ']
# 160  ['Success: Final output matches the expected r...
# 162  ["Error: Compilation error: /tmp/tmp3fdu6o8p/T...
# 165  ['Success: Final output matches the expected r...
# 167  ["Error: Compilation error: /tmp/tmpzsqflkps/T...
#
#     post_process_pass_ratio  2nd_post_process_steps             Type  \
# 365                     0.0           indented_code  Global_Variable
# 368                     0.0           indented_code  Global_Variable
# 371                     0.0           indented_code            Class
# 379                     0.0           indented_code            Class
# 389                     0.0           indented_code  Global_Variable
# ..                      ...                     ...              ...
# 158                     0.0           indented_code         Variable
# 160                     1.0           indented_code         Variable
# 162                     0.0           indented_code         Variable
# 165                     1.0            trimmed_code         Variable
# 167                     0.0           indented_code         Function
#
#     usage_line def_line abs_diff  \
# 365         76       13       63
# 368         79       14       65
# 371        108       11       97
# 379        116       11      105
# 389        151       94       57
# ..         ...      ...      ...
# 158        541      481       60
# 160        559      553        6
# 162        566      553       13
# 165        568      564        4
# 167        573      466      107
#
#                                         list_of_tuples comment_dist  \
# 365  [(76, 74), (79, 78), (107, 104), (116, 115), (...            2
# 368  [(76, 74), (79, 78), (107, 104), (116, 115), (...            1
# 371  [(76, 74), (79, 78), (107, 104), (116, 115), (...            3
# 379  [(76, 74), (79, 78), (107, 104), (116, 115), (...            1
# 389  [(76, 74), (79, 78), (107, 104), (116, 115), (...            2
# ..                                                 ...          ...
# 158  [(167, 23), (190, 189), (212, 189), (215, 189)...            2
# 160  [(167, 23), (190, 189), (212, 189), (215, 189)...            4
# 162  [(167, 23), (190, 189), (212, 189), (215, 189)...            5
# 165  [(167, 23), (190, 189), (212, 189), (215, 189)...            7
# 167  [(167, 23), (190, 189), (212, 189), (215, 189)...            2
#
#      range_class
# 365        Short
# 368        Short
# 371        Short
# 379        Short
# 389        Short
# ..           ...
# 158        Short
# 160        Short
# 162        Short
# 165        Short
# 167        Short
#
# [278 rows x 28 columns]
